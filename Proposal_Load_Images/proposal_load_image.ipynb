# %% [markdown]
# # Mini Project T2 - Team 1 - Image Acquisition for Project A

# %% [markdown]
# ## Setup

# %%
import sys
# Python 3.7 is required
assert sys.version_info >= (3, 7)

import cv2 as cv
import numpy as np

# Make sure that OpenCV optimization is enabled
if not cv.useOptimized():
    cv.setUseOptimized(True)
    
cv.useOptimized()
# Out:
# True

# %% [markdown]
# ## Load and Display Random Images

# %%
import matplotlib.pyplot as plt
import os
import numpy
import cv2 as cv
import numpy as np

# "images/" is the local file path where all the 4170 images located at
files = np.random.choice(os.listdir("images/"), size=20, replace=True)
img_dir = "images/"

plt.figure(figsize=(10, 8))
for i, img_file in enumerate(files):
    img = cv.imread(img_dir + img_file)
    
    img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    plt.subplot(5, 4, i+1)
    plt.imshow(img_rgb)
    
plt.show()

# %% [markdown]
# ## Images of Different Classes of Variation Factors

# %% [markdown]
# ### 1. Deformed Sign

# %%
img_1 = cv.imread('images/deformed_object.png')
cv.imshow('Deformed Object', img_1)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 2. Sign with Cluttered Background

# %%
img_2 = cv.imread('images/cluttered_background.png')
cv.imshow('Cluttered Background', img_2)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 3. Low Brightness Sign

# %%
img_3 = cv.imread('images/low_brightness.png')
cv.imshow('Low Brightness', img_3)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 4. Physically Damaged Sign

# %%
img_4 = cv.imread('images/physically_damaged.png')
cv.imshow('Physically Damaged', img_4)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 5. Sign with Same Colour as Background

# %%
img_5 = cv.imread('images/same_background_colour.png')
cv.imshow('Same as Background Colour', img_5)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 6. Shadow Obscured Sign

# %%
img_6 = cv.imread('images/shadow_obscured.png')
cv.imshow('Shadow Obscured Sign', img_6)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### 7. Same Object with Different Colours

# %%
img_7a = cv.imread('images/diff_colour_1.png')
cv.imshow('Same Sign with Colour 1 ', img_7a)

img_7b = cv.imread('images/diff_colour_2.png')
cv.imshow('Same Sign with Colour 2 ', img_7b)

cv.waitKey(0)
cv.destroyAllWindows()
