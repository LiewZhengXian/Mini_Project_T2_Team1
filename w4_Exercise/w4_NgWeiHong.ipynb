# %% [markdown]
# ## Weekly Activity

# %% [markdown]
# import cv2 as cv
# import numpy as np
# import matplotlib.pyplot as plt
#
# if not cv.useOptimized():
#     cv.useOptimized(True)
#
# cv.useOptimized()

# %% [markdown]
# ##### 1) Create a random noise color and grayscale image. You can set your own width and height, but keep the total number of pixels of both images identical.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

if not cv.useOptimized():
    cv.useOptimized(True)

cv.useOptimized()
# Out:
# True

# %%
rnc = np.random.default_rng(88)

color_arr = rnc.integers(0, high=256, size=(100, 100, 3), dtype="uint8")
gray_arr = rnc.integers(0, high=256, size=(300, 100), dtype="uint8")

plt.subplot(1, 2, 1)
plt.imshow(color_arr)
plt.title("color image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(gray_arr, cmap="gray", vmin=0, vmax=255)
plt.title("grayscale image")
plt.axis("off")

# num of pixel = 100*100*3=30000 & 300*100=30000
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ##### 2) Convert the code chunk found under section Divide an image into smaller patches using cropping into a function with the following signature:
# crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color)
#  #img is the source image
#  #num_horizontal_grid and num_vertical_grid are the number of patches along x and y axes.
#  #line_color is the color of the grid line.
#  #The output of the function should be image with grids

# %%
def crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color):
    """
    Arguments
    ----------------
    img: source image
    num_horizontal_grid: number of patches along x
    num_vertical_grid: number of patches along y
    line_color: color of the grid line

    Return
    --------
    image with grid
    """
    img_copy = img.copy()
    
    height, width = img.shape[:2]
    
    M, N = int(height / num_vertical_grid), int(width / num_horizontal_grid)

    x1, y1 = 0, 0

    for y in range(0, height, M):
        for x in range(0, width, N):
        
            y1 = y + M
            x1 = x + N
        
            if x1>=width and y1>=height:
                x1 = width-1
                y1 = height-1
                tile = img[y:height, x:width]
                cv.rectangle(img_copy, (x,y), (x1, y1), line_color, 1)
                cv.imshow('tile', tile)
            
            elif y1>=height:
                y1 = height-1
                cv.rectangle(img_copy, (x, y), (x1, y1), line_color, 1)
            
            elif x1>=width:
                x1 = width-1
                cv.rectangle(img_copy, (x, y), (x1, y1), line_color, 1)
            
            else:
                cv.rectangle(img_copy, (x, y), (x1, y1), line_color, 1)

    return img_copy

# %%
img = cv.imread('/Downloads/images/dog.jfif')

num_horizontal_grid = 3
num_vertical_grid = 2
line_color = (0, 255, 0)

grid_image = crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color)

cv.imshow('Patched Image', grid_image)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# [ WARN:0@46.169] global loadsave.cpp:241 findDecoder imread_('/Downloads/images/dog.jfif'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 num_vertical_grid = 2
#       5 line_color = (0, 255, 0)
# ----> 7 grid_image = crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color)
#       9 cv.imshow('Patched Image', grid_image)
#      10 cv.waitKey(0)
#
# Cell In[9], line 14, in crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color)
#       1 def crop_grid(img, num_horizontal_grid, num_vertical_grid, line_color):
#       2     """
#       3     Arguments
#       4     ----------------
#    (...)
#      12     image with grid
#      13     """
# ---> 14     img_copy = img.copy()
#      16     height, width = img.shape[:2]
#      18     M, N = int(height / num_vertical_grid), int(width / num_horizontal_grid)
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# ##### 3) How would you change the brightness of a color image? Suggest two ways to perform the image processing operations. Implement your methods by providing the example codes. You are free to choose any image.

# %%
# method 1: hsv

from utils import display_images
img = cv.imread("images/dog.jfif")
img_hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

h, s, v = cv.split(img_hsv)
v_new = np.zeros_like(v) + 100
v_new = np.uint8(v_new)

transform = cv.merge((h, s, v_new))
transform_display = cv.cvtColor(transform, cv.COLOR_HSV2BGR)

display_images([img, transform_display], ("original", "changed"))

# %%
# METHOD 2: point

def point_op(img, alpha, beta):
    img = img.astype(np.float32)
    res = alpha * img + beta

    res = np.clip(res, 0, 255)
    return np.uint8(res)

# %% [markdown]
# ##### 4) Provide at least one common use cases for the following color spaces:
#
# - RGB
# - HSV
# - CIELAB

# %% [markdown]
# #####
# - RGB: Digital Imaging and Display
# - HSV: Color Selection and Manipulation
# - CIELAB: Color Correction and Matching
